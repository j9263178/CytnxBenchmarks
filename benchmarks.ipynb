# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Two 2-leg tensors contraction with fixed quantum number blocks.
# Codes that reproduce the datas refer to cytnx/contraction.py & itensor/contraction.cc

# %%
## Codes that reproduce the datas refer to cytnx/contraction.py & itensor/contraction.cc

dims = 2*np.asarray([100, 200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000])
dense_it = [0.536282 ,2.11486 ,14.2201 ,44.6893 ,116.195 ,197.47 ,344.439 ,577.965 ,852.414 ,1303.52 ,1897.09] # ms
dense_cy = [0.0003718852996826172, 0.0007133960723876953, 0.0033198833465576173, 0.009342241287231445, 0.024475860595703124, 0.048480224609375, 0.06552982330322266, 0.09995179176330567, 0.1509995460510254, 0.20548019409179688, 0.2863144397735596] # ms
sparse_it = [0.168561 ,0.898121 ,3.99395 ,14.2394 ,29.2381 ,52.8324 ,84.1215 ,146.155 ,215.958 ,310.889 ,569.071] # ms
sparse_cy = [0.0006237030029296875, 0.00113067626953125, 0.003004932403564453, 0.006267690658569336, 0.010949325561523438, 0.01792311668395996, 0.027394914627075197, 0.039742326736450194, 0.059447956085205075, 0.08089351654052734, 0.10941720008850098] # ms
dense_np = [0.0014153242111206055, 0.0002991914749145508, 0.0039511919021606445, 0.0058063030242919925, 0.009206485748291016, 0.011583685874938965, 0.030704522132873537, 0.03471331596374512, 0.03826744556427002, 0.04959979057312012, 0.05253615379333496]
plt.subplots(dpi = 120)
plt.plot(dims, dense_it, marker = 'o',label = "Itensor (dense)", color = "orangered")
plt.plot(dims, sparse_it,marker = 'o', label = "Itensor (sparse)", color = "salmon")
plt.plot(dims, 1000*np.asarray(dense_cy),marker = 'o', label = "Cytnx (dense)", color = "forestgreen")
plt.plot(dims, 1000*np.asarray(sparse_cy),marker = 'o', label = "Cytnx (sparse)", color = "mediumaquamarine")

plt.legend()
plt.xlabel("D")
plt.ylabel("Contraction time (ms)")
plt.show()

# %% [markdown]
# #### Computation time for a whole two-sites update process in DMRG
# XX chain, Nsites = 16, maximum D = 64. Codes that reproduce the datas refer to cytnx/dmrg_U1.py.

# %%
alltime = [0.006806612014770508, 0.0071315765380859375, 0.007063150405883789, 0.007007598876953125, 0.007001161575317383, 0.0070307254791259766, 0.007115602493286133, 0.007144927978515625, 0.0070760250091552734, 0.007055044174194336, 0.007053852081298828, 0.007037639617919922, 0.007011890411376953, 0.007042884826660156, 0.007071018218994141, 0.00694727897644043, 0.009445428848266602, 0.011898517608642578, 0.01189875602722168, 0.011871337890625, 0.011867284774780273, 0.011895418167114258, 0.011845827102661133, 0.011866092681884766, 0.011907577514648438, 0.011905193328857422, 0.0118560791015625, 0.011867523193359375, 0.011828422546386719, 0.009211063385009766, 0.00867772102355957, 0.0113372802734375, 0.018099546432495117, 0.02647566795349121, 0.026519060134887695, 0.026402711868286133, 0.0264739990234375, 0.026500701904296875, 0.026462793350219727, 0.02645421028137207, 0.026501893997192383, 0.02650761604309082, 0.026384592056274414, 0.018220901489257812, 0.009214162826538086, 0.008671760559082031, 0.01670241355895996, 0.025197267532348633, 0.04574108123779297, 0.08149218559265137, 0.08141636848449707, 0.08146333694458008, 0.08137249946594238, 0.08149027824401855, 0.08158612251281738, 0.08326029777526855, 0.0816643238067627, 0.04737663269042969, 
037422180175781, 0.0010192394256591797, 0.0011043548583984375, 0.0014998912811279297, 0.0027799606323242188, 0.008569002151489258, 0.016093015670776367, 0.031752586364746094, 0.03061532974243164, 0.03202509880065918, 0.01727128028869629, 0.00972604751586914, 0.003229856491088867, 0.001512289047241211, 0.0011246204376220703, 0.0010607242584228516, 0.0010280609130859375, 0.0011076927185058594, 0.0015265941619873047, 0.003125905990600586, 0.009589433670043945, 0.017560243606567383, 0.030976533889770508, 0.03127789497375488, 0.032315969467163086, 0.016005516052246094, 0.008303403854370117, 0.0027875900268554688, 0.0015168190002441406, 0.0011017322540283203, 0.0010077953338623047, 0.0010249614715576172, 0.0010998249053955078, 0.0015079975128173828, 0.002874612808227539, 0.008302450180053711, 0.016050100326538086, 0.03139519691467285, 0.031154155731201172, 0.03179788589477539, 0.016817092895507812, 0.009674310684204102, 0.003252267837524414, 0.0015256404876708984, 0.0011298656463623047, 0.0010631084442138672, 0.0010271072387695312, 0.0011410713195800781, 0.0015153884887695312, 0.0030918121337890625, 0.009896278381347656, 0.01699209213256836, 0.03101801872253418, 0.03073263168334961, 0.03155517578125, 0.015866756439208984, 0.008220195770263672, 0.002763509750366211, 0.0014913082122802734, 0.0010972023010253906, 0.0010380744934082031, 0.0010044574737548828, 0.0011048316955566406, 0.0015218257904052734, 0.002755880355834961, 0.008315563201904297, 0.01598834991455078, 0.03166818618774414, 0.030863523483276367, 0.030610084533691406, 0.017083406448364258, 0.009895086288452148, 0.003198862075805664, 0.0015108585357666016, 0.0011637210845947266, 0.001062631607055664]

fig, ax = plt.subplots(dpi = 120)
swe = 15*np.asarray([i for i in range(10)])
for sw in swe:
    ax.axvline(sw, color = 'gray',linestyle = '--', linewidth = 1.2)

plt.plot(1000*np.asarray(opttime_dense), marker = '.', label = "Lanczos(Dense)")
plt.plot(1000*np.asarray(opttime), marker = '.', label = "Lanczos(U1)")
plt.legend()
plt.ylabel("Computation time (ms)")
plt.xlabel("two site update")
plt.show()

fig, ax = plt.subplots(dpi = 120)
for sw in swe:
    ax.axvline(sw, color = 'gray',linestyle = '--', linewidth = 1.2)

plt.plot(1000*np.asarray(alltime_dense)-1000*np.asarray(opttime_dense), marker = '.', label = "other computation(Dense)")
plt.plot(1000*np.asarray(alltime)-1000*np.asarray(opttime), marker = '.', label = "other computation(U1)")
plt.legend()
plt.ylabel("Computation time (ms)")
plt.xlabel("two site update")
plt.show()

# %% [markdown]
# #### Environment-site contraction in dmrg
# Contraction time for a environment LR contracted with a A/B in cytnx dmrg code.

# %%
dims = [2,4,8,16,32,64]
timeU1 = [0.00020432472229003906, 0.00041747093200683594, 0.0010294914245605469,  0.003061056137084961, 0.009993791580200195, 0.03607487678527832]
timeDense = [4.00543212890625e-05, 4.076957702636719e-05,  4.649162292480469e-05, 7.05718994140625e-05, 0.0001442432403564453, 0.00043129920959472656]
fig, ax = plt.subplots(dpi = 120)
plt.plot(dims, 1000*np.asarray(timeU1), marker = "o", label = 'U1')
plt.plot(dims, 1000*np.asarray(timeDense), marker = "o", label = 'Dense')
plt.legend()
plt.xlabel("D")
plt.ylabel("Computation time (ms)")
plt.show()
